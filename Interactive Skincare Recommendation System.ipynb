# %% [markdown]
# # Interactive Codes

# %% [markdown]
# ### There are 2 sections:
# ##### 1. Bokeh Graphs for all products in differing categories
# ##### 2. Personalised Skincare Recommendation System
#
#
# This is where the magic happens! For a detailed explanation of section 1, please refer to the previous jupyter notebook on github. In this notebook, we fully make use of Bokeh's interactive power, and graph out different combinations of product type and skin type. In section 2, users of the recommendation system can select a certain product and find other similar products. It is best to know your skin type as well, but we have included an option if you are unsure of your skin type too!
#
# Do run the code in order for the system to function! It may take a while as we have re-run the UMAP function.

# %% [markdown]
# ## Section 1: Bokeh Graph

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
sb.set()

# importing the data

cosmeticsdata = pd.read_csv('cosmetics.csv')

# %%
# installing UMAP

# !pip install umap-learn

import umap

import numba
# Out:
# Requirement already satisfied: umap-learn in c:\users\nyan\anaconda3\lib\site-packages (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\nyan\anaconda3\lib\site-packages (from umap-learn) (0.5.6)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\nyan\anaconda3\lib\site-packages (from umap-learn) (0.24.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\nyan\anaconda3\lib\site-packages (from umap-learn) (1.20.1)
# Requirement already satisfied: numba>=0.49 in c:\users\nyan\anaconda3\lib\site-packages (from umap-learn) (0.53.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\nyan\anaconda3\lib\site-packages (from umap-learn) (1.6.2)
# Requirement already satisfied: tqdm in c:\users\nyan\anaconda3\lib\site-packages (from umap-learn) (4.59.0)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\nyan\anaconda3\lib\site-packages (from numba>=0.49->umap-learn) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\nyan\anaconda3\lib\site-packages (from numba>=0.49->umap-learn) (52.0.0.post20210125)
# Requirement already satisfied: joblib>=0.11 in c:\users\nyan\anaconda3\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nyan\anaconda3\lib\site-packages (from scikit-learn>=0.22->umap-learn) (2.1.0)

# %%
from sklearn.metrics.pairwise import cosine_similarity

from bokeh.io import show, curdoc, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, Select, Paragraph, TextInput
from bokeh.layouts import widgetbox, column, row
from ipywidgets import interact

# %%
cosmeticsdata = cosmeticsdata[cosmeticsdata["Ingredients"].str.contains("Visit") == False]
cosmeticsdata = cosmeticsdata[cosmeticsdata["Ingredients"].str.contains("No Info") == False]
cosmeticsdata = cosmeticsdata[cosmeticsdata["Ingredients"].str.contains("NAME") == False]
cosmeticsdata = cosmeticsdata[cosmeticsdata["Ingredients"].str.contains("product package") == False]

cosmeticsdata = cosmeticsdata.set_index('Name')

# %%
moisturizer = cosmeticsdata[cosmeticsdata["Label"].str.contains("Moisturizer") == True]
facemask = cosmeticsdata[cosmeticsdata["Label"].str.contains("Face Mask") == True]
cleanser = cosmeticsdata[cosmeticsdata["Label"].str.contains("Cleanser") == True]
treatment = cosmeticsdata[cosmeticsdata["Label"].str.contains("Treatment") == True]
eyecream = cosmeticsdata[cosmeticsdata["Label"].str.contains("Eye cream") == True]
sunprotect = cosmeticsdata[cosmeticsdata["Label"].str.contains("Sun protect") == True]

# %%
option_1 = cosmeticsdata.Label.unique().tolist()
option_2 = cosmeticsdata.columns[5:].tolist()

# %% [markdown]
# ##### This function is to calculate the x and y values of UMAP for each category of product for the plotting of Bokeh graphs later.

# %%
def recommendation(op1, op2):
    dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
    dataset1 = dataset1.reset_index()
    
    index = 0
    ingredient_dict = {}
    corpus = []

    for i in range(len(dataset1)):
        ingredients = dataset1['Ingredients'][i]
        ingredients_lower = ingredients.lower()        # change all to lower case
        tokens = ingredients_lower.split(', ')         # split up the ingredients from the string
        corpus.append(tokens)
        for ingredient in tokens:
            if ingredient not in ingredient_dict:      # prevents duplication
                ingredient_dict[ingredient] = index
                index += 1
            
    # maxtrix that is filled with binary values 
    # to check if ingredient is present or absent
    # if present, it will be 1
    # if absent, it will be 0

    M = len(dataset1)           # number of products
    N = len(ingredient_dict)    # number of ingredients
    
    # initialise matrix with 0s
    matrix = np.zeros(shape = (M, N))
    
    
    def one_hot_encoder(tokens):
        x = np.zeros(N)
        for ingredient in tokens:
            index = ingredient_dict[ingredient]
            x[index] = 1
        return x
    
    # make a DTM
    i = 0
    for tokens in corpus:
        matrix[i, :] = one_hot_encoder(tokens)
        i += 1
        
    # dimension reduction with UMAP

    umap_data = umap.UMAP(n_components = 2, min_dist = 0.7, n_neighbors = 5, random_state = 1).fit_transform(matrix)

    # adding 2 new columns X and Y to the dataset

    dataset1['X'] = umap_data[:, 0]
    dataset1['Y'] = umap_data[:, 1]

    return dataset1

# %% [markdown]
# ##### Create a new CSV file. This file contains more rows of data as each product may cater to different skin types and we are only comparing products within the same category to obtain UMAP values. Hence, multiple rows may exist for each product, containing different sets of X and Y values.
#
# ##### For example, product X is suitable for combination and oily skin. 2 rows will be created for product X. One row contains the X and Y values for product X when compared to other products for combination skin and the other row contains X and Y values for the same product when compared to other products for oily skin.
#
# ##### Hence, this new CSV file will contain more rows of data compared to the original dataset "cosmetics.csv".
#
# ##### Since there are 5 categories of skintype and  6 product types, there will be a total of 30 unique labels. For example, Cleanser_Oily, Cleanser_Combination.

# %%
dataset_all = pd.DataFrame()

for op1 in option_1:
    for op2 in option_2:
        temp = recommendation(op1, op2)
        temp['Label'] = op1 + '_' + op2
        dataset_all = pd.concat([dataset_all, temp])
        
dataset_all.to_csv('newData.csv', encoding = 'utf-8-sig', index = False)
# Out:
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]
# <ipython-input-7-65688a8ff4ff>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataset1 = cosmeticsdata[cosmeticsdata["Label"] == op1][cosmeticsdata[op2] == 1]

# %%
ds = pd.read_csv('newData.csv')
ds
# Out:
#                                                    Name  \
# 0                                       Crème de la Mer
# 1                              Facial Treatment Essence
# 2                            Protini™ Polypeptide Cream
# 3                           The Moisturizing Soft Cream
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+
# ...                                                 ...
# 4092  Prime & Protect Mattifying Primer with Broad S...
# 4093  Quick Dry Body Spray With SolSci-X™ Broad Spec...
# 4094          Sport Continuous Spray SPF 30 - Unscented
# 4095  Anti-Aging Armour™ Super Smart Skin-Perfecting...
# 4096  Yoghurt Nourishing Fluid Veil Face Sunscreen B...
#
#                         Label            Brand  Price  Rank  \
# 0     Moisturizer_Combination           LA MER    175   4.1
# 1     Moisturizer_Combination            SK-II    179   4.1
# 2     Moisturizer_Combination   DRUNK ELEPHANT     68   4.4
# 3     Moisturizer_Combination           LA MER    175   3.8
# 4     Moisturizer_Combination     IT COSMETICS     38   4.1
# ...                       ...              ...    ...   ...
# 4092    Sun protect_Sensitive    CANE + AUSTIN     56   4.2
# 4093    Sun protect_Sensitive  MDSOLARSCIENCES     20   3.9
# 4094    Sun protect_Sensitive            COOLA     32   5.0
# 4095    Sun protect_Sensitive     IT COSMETICS     38   4.1
# 4096    Sun protect_Sensitive           KORRES     35   3.9
#
#                                             Ingredients  Combination  Dry  \
# 0     Algae (Seaweed) Extract, Mineral Oil, Petrolat...            1    1
# 1     Galactomyces Ferment Filtrate (Pitera), Butyle...            1    1
# 2     Water, Dicaprylyl Carbonate, Glycerin, Ceteary...            1    1
# 3     Algae (Seaweed) Extract, Cyclopentasiloxane, P...            1    1
# 4     Water, Snail Secretion Filtrate, Phenyl Trimet...            1    1
# ...                                                 ...          ...  ...
# 4092  Ascorbic Acid, Biotin, Camellia Sinensis (Gree...            1    1
# 4093  SD Alcohol 40, Butyloctyl Salicylate, Polyeste...            1    1
# 4094  Alcohol (Organic), Algae Extract (Organic), Al...            1    1
# 4095  Water, Cyclopentasiloxane, Butyloctyl Salicyla...            1    1
# 4096  Water, Alcohol Denat., Potassium Cetyl Phospha...            1    1
#
#       Normal  Oily  Sensitive          X         Y
# 0          1     1          1 -36.783270 -0.657504
# 1          1     1          1 -34.058930 -6.004477
# 2          1     1          0 -33.301850 -4.885534
# 3          1     1          1 -21.033564 -6.323969
# 4          1     1          1 -30.736635 -1.904555
# ...      ...   ...        ...        ...       ...
# 4092       1     1          1  10.137806 -6.583157
# 4093       1     1          1   8.814378 -7.859425
# 4094       1     1          1  11.213762 -9.818619
# 4095       1     1          1  11.813240 -4.390383
# 4096       1     1          1   9.951548 -7.617050
#
# [4097 rows x 13 columns]

# %%
ds.Label.unique()
# Out:
# array(['Moisturizer_Combination', 'Moisturizer_Dry', 'Moisturizer_Normal',
#        'Moisturizer_Oily', 'Moisturizer_Sensitive',
#        'Cleanser_Combination', 'Cleanser_Dry', 'Cleanser_Normal',
#        'Cleanser_Oily', 'Cleanser_Sensitive', 'Treatment_Combination',
#        'Treatment_Dry', 'Treatment_Normal', 'Treatment_Oily',
#        'Treatment_Sensitive', 'Face Mask_Combination', 'Face Mask_Dry',
#        'Face Mask_Normal', 'Face Mask_Oily', 'Face Mask_Sensitive',
#        'Eye cream_Combination', 'Eye cream_Dry', 'Eye cream_Normal',
#        'Eye cream_Oily', 'Eye cream_Sensitive', 'Sun protect_Combination',
#        'Sun protect_Dry', 'Sun protect_Normal', 'Sun protect_Oily',
#        'Sun protect_Sensitive'], dtype=object)

# %%
# Load Bokeh Visualisation App

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# function to filter the data according to label

def newDataset(dataset, option):
    dataFrame = pd.DataFrame()
    dataFrame = ds[ds['Label'] == option]
    return dataFrame

# %%
# function to create a Bokeh plot

def make_plot(src):
    p = figure(width = 500, height = 400, 
                  x_axis_label = 'UMAP 1',
                  y_axis_label = 'UMAP 2')

    p.circle(x = 'X', y = 'Y', source = src,
                size = 10, color = "olive", alpha = 0.8)

    p.background_fill_color = "beige"
    p.background_fill_alpha = 0.5

    # adding a hover tool

    hover = HoverTool(tooltips = [('Product', '@Name'),
                                  ('Brand', '@Brand'), 
                                  ('Price', '$@Price'), 
                                  ('Rank', '@Rank')])

    p.add_tools(hover)
    
    push_notebook()  
    show(p, notebook_handle = True)

# %%
# define the callback
def update(op1 =option_1[0], op2 = option_2[0]):
    a_b = op1 + '_' + op2
    toplot = newDataset(ds, a_b)
    make_plot(toplot)

# %% [markdown]
# # Get Bokeh Graphs for each product category

# %%
# interact the plot with callback 
interact(update, op1 = option_1, op2 = option_2)
# Out:
# interactive(children=(Dropdown(description='op1', options=('Moisturizer', 'Cleanser', 'Treatment', 'Face Mask'…
# <function __main__.update(op1='Moisturizer', op2='Combination')>

# %% [markdown]
# # Section 2: Personalised Recommendation System
# ## User input to get recommended products
# ### Section 2.1: Skin type is known
# #### The code below intakes user's choice of product for comparison and his/her skintype. The skintype is needed to get more accurate estimates of similar products.

# %%
# import math library
from math import dist

# %%
dsCopy = ds.copy()
dsCopy = dsCopy.set_index('Name')

# %% [markdown]
# ### Run the code below to input your choice of product.
# Check the 'cosmetics.csv' file for the full list of products.

# %%
while True:
    choiceProduct = input("Please enter the product you want to get similar products for: ")         
    choiceSkinType = input("Please enter your skin type (Combination/Dry/Oily/Sensitive/Normal): ")

    myItem = dsCopy.loc[[choiceProduct]]
    if myItem[choiceSkinType].values[0]==1:
        break
        
    if myItem[choiceSkinType].values[0]==0:
        print("Please note that this product is not suitable for your skintype. Try again!")
            
            
print("Successfully updated data")
# Out:
# Please enter the product you want to get similar products for: Purity Made Simple Cleanser
# Please enter your skin type (Combination/Dry/Oily/Sensitive/Normal): Combination
# Successfully updated data

# %%
pdt = cosmeticsdata.loc[[choiceProduct]]

# get product type
pdtType = pdt['Label'].values[0]

fullLabel = pdtType + '_' + choiceSkinType

# %%
dataset1 = dsCopy.copy()
dataset1 = dataset1[dataset1['Label'] == fullLabel]

dataset1
# Out:
#                                                                    Label  \
# Name
# T.L.C. Sukari Babyfacial™                           Cleanser_Combination
# T.L.C. Framboos™ Glycolic Night Serum               Cleanser_Combination
# Green Clean Makeup Meltaway Cleansing Balm with...  Cleanser_Combination
# Purity Made Simple Cleanser                         Cleanser_Combination
# The Rice Polish Foaming Enzyme Powder               Cleanser_Combination
# ...                                                                  ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm         Cleanser_Combination
# Blue Herbal Acne Cleanser Treatment                 Cleanser_Combination
# Pore Refining Detox Double Cleanse                  Cleanser_Combination
# Herbal-Infused Micellar Cleansing Water             Cleanser_Combination
# Refreshing Gel Cleanser                             Cleanser_Combination
#
#                                                                  Brand  Price  \
# Name
# T.L.C. Sukari Babyfacial™                               DRUNK ELEPHANT     80
# T.L.C. Framboos™ Glycolic Night Serum                   DRUNK ELEPHANT     90
# Green Clean Makeup Meltaway Cleansing Balm with...             FARMACY     34
# Purity Made Simple Cleanser                                 PHILOSOPHY     24
# The Rice Polish Foaming Enzyme Powder                           TATCHA     65
# ...                                                                ...    ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm         REN CLEAN SKINCARE     32
# Blue Herbal Acne Cleanser Treatment                 KIEHL'S SINCE 1851     22
# Pore Refining Detox Double Cleanse                         ERNO LASZLO     55
# Herbal-Infused Micellar Cleansing Water             KIEHL'S SINCE 1851     28
# Refreshing Gel Cleanser                                     CLARISONIC     19
#
#                                                     Rank  \
# Name
# T.L.C. Sukari Babyfacial™                            4.5
# T.L.C. Framboos™ Glycolic Night Serum                4.3
# Green Clean Makeup Meltaway Cleansing Balm with...   4.6
# Purity Made Simple Cleanser                          4.5
# The Rice Polish Foaming Enzyme Powder                4.4
# ...                                                  ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm          4.2
# Blue Herbal Acne Cleanser Treatment                  3.5
# Pore Refining Detox Double Cleanse                   5.0
# Herbal-Infused Micellar Cleansing Water              3.7
# Refreshing Gel Cleanser                              5.0
#
#                                                                                           Ingredients  \
# Name
# T.L.C. Sukari Babyfacial™                           Water, Glycolic Acid, Hydroxyethyl Acrylate/So...
# T.L.C. Framboos™ Glycolic Night Serum               Water, Glycolic Acid, Butylene Glycol, Glyceri...
# Green Clean Makeup Meltaway Cleansing Balm with...  Cetyl Ethylhexanoate, Caprylic/Capric Triglyce...
# Purity Made Simple Cleanser                         Water, Sodium Lauroamphoacetate, Sodium Tridec...
# The Rice Polish Foaming Enzyme Powder               Microcrystalline Cellulose, Oryza Sativa (Rice...
# ...                                                                                               ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm         Prunus Amygdalus Dulcis (Sweet Almond) Oil, Ce...
# Blue Herbal Acne Cleanser Treatment                 Water, Coco-Glucoside, Propylene Glycol, Ammon...
# Pore Refining Detox Double Cleanse                  Water, Propanediol, Sodium C14-16 Olefin Sulfo...
# Herbal-Infused Micellar Cleansing Water             Water, Glycerin, Propanediol, Melissa Officina...
# Refreshing Gel Cleanser                             Water, Glycerin, Coco-Betaine, Sodium Cocoyl G...
#
#                                                     Combination  Dry  Normal  \
# Name
# T.L.C. Sukari Babyfacial™                                     1    1       1
# T.L.C. Framboos™ Glycolic Night Serum                         1    1       1
# Green Clean Makeup Meltaway Cleansing Balm with...            1    1       1
# Purity Made Simple Cleanser                                   1    1       1
# The Rice Polish Foaming Enzyme Powder                         1    1       1
# ...                                                         ...  ...     ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm                   1    1       1
# Blue Herbal Acne Cleanser Treatment                           1    0       0
# Pore Refining Detox Double Cleanse                            1    1       1
# Herbal-Infused Micellar Cleansing Water                       1    1       1
# Refreshing Gel Cleanser                                       1    1       1
#
#                                                     Oily  Sensitive         X  \
# Name
# T.L.C. Sukari Babyfacial™                              1          0  0.099580
# T.L.C. Framboos™ Glycolic Night Serum                  1          0 -0.206441
# Green Clean Makeup Meltaway Cleansing Balm with...     1          1  4.908966
# Purity Made Simple Cleanser                            1          1 -0.032383
# The Rice Polish Foaming Enzyme Powder                  1          1  4.549874
# ...                                                  ...        ...       ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm            1          1  2.008253
# Blue Herbal Acne Cleanser Treatment                    1          0  2.426944
# Pore Refining Detox Double Cleanse                     1          1  3.898748
# Herbal-Infused Micellar Cleansing Water                1          1  3.324823
# Refreshing Gel Cleanser                                1          1  1.860473
#
#                                                            Y
# Name
# T.L.C. Sukari Babyfacial™                          -4.152148
# T.L.C. Framboos™ Glycolic Night Serum              -2.147541
# Green Clean Makeup Meltaway Cleansing Balm with... -4.720349
# Purity Made Simple Cleanser                        -0.917829
# The Rice Polish Foaming Enzyme Powder              -1.429712
# ...                                                      ...
# Rosa Centifolia™ No.1 Purity Cleansing Balm        -2.049911
# Blue Herbal Acne Cleanser Treatment                -3.208080
# Pore Refining Detox Double Cleanse                 -2.811092
# Herbal-Infused Micellar Cleansing Water            -4.320712
# Refreshing Gel Cleanser                            -5.442932
#
# [153 rows x 12 columns]

# %%
myItem = myItem[myItem['Label'] == fullLabel]
myItem
# Out:
#                                             Label       Brand  Price  Rank  \
# Name
# Purity Made Simple Cleanser  Cleanser_Combination  PHILOSOPHY     24   4.5
#
#                                                                    Ingredients  \
# Name
# Purity Made Simple Cleanser  Water, Sodium Lauroamphoacetate, Sodium Tridec...
#
#                              Combination  Dry  Normal  Oily  Sensitive  \
# Name
# Purity Made Simple Cleanser            1    1       1     1          1
#
#                                     X         Y
# Name
# Purity Made Simple Cleanser -0.032383 -0.917829

# %%
# obtain X and Y values for choice product and skintype

point1 = np.array([myItem['X'], myItem['Y']])

point1
# Out:
# array([[-0.03238258],
#        [-0.91782874]])

# %%
# create a new column

dataset1['Distance'] = 0.0

# %%
# other items

for i in range(len(dataset1)):
    point2 = np.array([dataset1['X'][i], dataset1['Y'][i]])
    dataset1.Distance[i] = dist(point1, point2)
# Out:
# <ipython-input-24-9d137dfa2f42>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset1.Distance[i] = dist(point1, point2)

# %%
# sorting data in ascending order

dataset1 = dataset1.sort_values('Distance')
dataset1.head(6)
# Out:
#                                                             Label  \
# Name
# Purity Made Simple Cleanser                  Cleanser_Combination
# Stay Balanced™ Oil Control Cleansing Cloths  Cleanser_Combination
# Alpha Beta® Pore Perfecting Cleansing Gel    Cleanser_Combination
# 8% Glycolic Solutions Toner                  Cleanser_Combination
# A Glowing Regimen Trial Set                  Cleanser_Combination
# 3% Glycolic Solutions Cleanser               Cleanser_Combination
#
#                                                                  Brand  Price  \
# Name
# Purity Made Simple Cleanser                                 PHILOSOPHY     24
# Stay Balanced™ Oil Control Cleansing Cloths               OLEHENRIKSEN      8
# Alpha Beta® Pore Perfecting Cleansing Gel    DR. DENNIS GROSS SKINCARE     38
# 8% Glycolic Solutions Toner                          PETER THOMAS ROTH     40
# A Glowing Regimen Trial Set                                 PHILOSOPHY     34
# 3% Glycolic Solutions Cleanser                       PETER THOMAS ROTH     38
#
#                                              Rank  \
# Name
# Purity Made Simple Cleanser                   4.5
# Stay Balanced™ Oil Control Cleansing Cloths   4.5
# Alpha Beta® Pore Perfecting Cleansing Gel     4.6
# 8% Glycolic Solutions Toner                   4.3
# A Glowing Regimen Trial Set                   4.8
# 3% Glycolic Solutions Cleanser                4.4
#
#                                                                                    Ingredients  \
# Name
# Purity Made Simple Cleanser                  Water, Sodium Lauroamphoacetate, Sodium Tridec...
# Stay Balanced™ Oil Control Cleansing Cloths  Water, Hamamelis Virginiana (Witch Hazel) Wate...
# Alpha Beta® Pore Perfecting Cleansing Gel    Water, Glycerin, Sodium Lauroyl Methyl Isethio...
# 8% Glycolic Solutions Toner                  Water, Glycolic Acid, Alcohol Denat., Methyl G...
# A Glowing Regimen Trial Set                  Purity Made Simple Cleanser: Water, Sodium Lau...
# 3% Glycolic Solutions Cleanser               Water, Sodium Laureth Sulfate, Propylene Glyco...
#
#                                              Combination  Dry  Normal  Oily  \
# Name
# Purity Made Simple Cleanser                            1    1       1     1
# Stay Balanced™ Oil Control Cleansing Cloths            1    0       0     1
# Alpha Beta® Pore Perfecting Cleansing Gel              1    1       1     1
# 8% Glycolic Solutions Toner                            1    1       1     1
# A Glowing Regimen Trial Set                            1    1       1     1
# 3% Glycolic Solutions Cleanser                         1    1       1     1
#
#                                              Sensitive         X         Y  \
# Name
# Purity Made Simple Cleanser                          1 -0.032383 -0.917829
# Stay Balanced™ Oil Control Cleansing Cloths          0 -0.119182 -1.188630
# Alpha Beta® Pore Perfecting Cleansing Gel            1  0.341612 -1.142170
# 8% Glycolic Solutions Toner                          1 -0.306905 -1.458793
# A Glowing Regimen Trial Set                          1 -0.806882 -1.206391
# 3% Glycolic Solutions Cleanser                       1  0.385867 -1.814362
#
#                                              Distance
# Name
# Purity Made Simple Cleanser                  0.000000
# Stay Balanced™ Oil Control Cleansing Cloths  0.284372
# Alpha Beta® Pore Perfecting Cleansing Gel    0.436120
# 8% Glycolic Solutions Toner                  0.606634
# A Glowing Regimen Trial Set                  0.826509
# 3% Glycolic Solutions Cleanser               0.989295

# %% [markdown]
# ### Section 2.2: Skin type is unknown
#
# ##### If the user does not know his/her skin type, we can get the UMAP values for products of all categories and plot a bokeh graph with these x and y values. This will give an estimate of the 5 most similar products, regardless of the user's skin type.
#
# ##### We need to obtain UMAP values for each product compared to every other product.

# %%
CD = cosmeticsdata.copy()

# %%
# tokenisation of the ingredients list 

index = 0
ingredient_dict = {}
corpus = []

for i in range(len(cosmeticsdata)):
    ingredients = CD['Ingredients'][i]
    ingredients_lower = ingredients.lower()        # change all to lower case
    tokens = ingredients_lower.split(', ')         # split up the ingredients from the string
    corpus.append(tokens)
    
    for ingredient in tokens:
        if ingredient not in ingredient_dict:      # prevents duplication
            ingredient_dict[ingredient] = index
            index += 1
  


# matrix that is filled with binary values 
# to check if ingredient is present or absent
# if present, it will be 1
# if absent, it will be 0
 
M = len(CD)           # number of products
N = len(ingredient_dict)    # number of ingredients

# initialise matrix with 0s

matrix1 = np.zeros(shape = (M, N))

# filling up the matrix

def one_hot_encoder(tokens):
    x = np.zeros(N)
    
    for ingredient in tokens:
        index = ingredient_dict[ingredient]
        x[index] = 1
    return x

i = 0

for tokens in corpus:
    matrix1[i, :] = one_hot_encoder(tokens)
    i += 1

# %% [markdown]
# #### Since this is comparing the product with all other products, we should preserve the global structure and set n_neighbors to a number closer to the maximum number of data (1284). This is to avoid too much focus on the finer details, which can make the results biased.
#
# ##### For example, setting n_neighbours to 5 (too small a number) will cause the 5 recommended results to be products of the same brand as the choice product.

# %%
# dimension reduction with UMAP

umap_data = umap.UMAP(n_components = 2, min_dist = 0.7, n_neighbors = 1000, random_state = 1).fit_transform(matrix1)

# adding 2 new columns X and Y to the dataset

CD['X'] = umap_data[:, 0]
CD['Y'] = umap_data[:, 1]

CD
# Out:
#                                                           Label  \
# Name
# Crème de la Mer                                     Moisturizer
# Facial Treatment Essence                            Moisturizer
# Protini™ Polypeptide Cream                          Moisturizer
# The Moisturizing Soft Cream                         Moisturizer
# Your Skin But Better™ CC+™ Cream with SPF 50+       Moisturizer
# ...                                                         ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...  Sun protect
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...  Sun protect
# Daily Deflector™ Waterlight Broad Spectrum SPF ...  Sun protect
# Self Tan Dry Oil SPF 50                             Sun protect
# Pro Light Self Tan Bronzing Mist                    Sun protect
#
#                                                                             Brand  \
# Name
# Crème de la Mer                                                            LA MER
# Facial Treatment Essence                                                    SK-II
# Protini™ Polypeptide Cream                                         DRUNK ELEPHANT
# The Moisturizing Soft Cream                                                LA MER
# Your Skin But Better™ CC+™ Cream with SPF 50+                        IT COSMETICS
# ...                                                                           ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...                KATE SOMERVILLE
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...                         KORRES
# Daily Deflector™ Waterlight Broad Spectrum SPF ...                KATE SOMERVILLE
# Self Tan Dry Oil SPF 50                                             VITA LIBERATA
# Pro Light Self Tan Bronzing Mist                    ST. TROPEZ TANNING ESSENTIALS
#
#                                                     Price  Rank  \
# Name
# Crème de la Mer                                       175   4.1
# Facial Treatment Essence                              179   4.1
# Protini™ Polypeptide Cream                             68   4.4
# The Moisturizing Soft Cream                           175   3.8
# Your Skin But Better™ CC+™ Cream with SPF 50+          38   4.1
# ...                                                   ...   ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...     48   3.9
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...     35   3.9
# Daily Deflector™ Waterlight Broad Spectrum SPF ...     48   3.6
# Self Tan Dry Oil SPF 50                                54   3.5
# Pro Light Self Tan Bronzing Mist                       20   1.0
#
#                                                                                           Ingredients  \
# Name
# Crème de la Mer                                     Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# Facial Treatment Essence                            Galactomyces Ferment Filtrate (Pitera), Butyle...
# Protini™ Polypeptide Cream                          Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# The Moisturizing Soft Cream                         Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# Your Skin But Better™ CC+™ Cream with SPF 50+       Water, Snail Secretion Filtrate, Phenyl Trimet...
# ...                                                                                               ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...  Water, Butylene Glycol, PEG-8, Glycerin, Undec...
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...  Water, Alcohol Denat., Potassium Cetyl Phospha...
# Daily Deflector™ Waterlight Broad Spectrum SPF ...  Water, Isododecane, Dimethicone, Butyloctyl Sa...
# Self Tan Dry Oil SPF 50                             Water, Dihydroxyacetone, Glycerin, Sclerocarya...
# Pro Light Self Tan Bronzing Mist                    Water, Dihydroxyacetone, Propylene Glycol, PPG...
#
#                                                     Combination  Dry  Normal  \
# Name
# Crème de la Mer                                               1    1       1
# Facial Treatment Essence                                      1    1       1
# Protini™ Polypeptide Cream                                    1    1       1
# The Moisturizing Soft Cream                                   1    1       1
# Your Skin But Better™ CC+™ Cream with SPF 50+                 1    1       1
# ...                                                         ...  ...     ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...            0    0       0
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...            1    1       1
# Daily Deflector™ Waterlight Broad Spectrum SPF ...            0    0       0
# Self Tan Dry Oil SPF 50                                       0    0       0
# Pro Light Self Tan Bronzing Mist                              0    0       0
#
#                                                     Oily  Sensitive  \
# Name
# Crème de la Mer                                        1          1
# Facial Treatment Essence                               1          1
# Protini™ Polypeptide Cream                             1          0
# The Moisturizing Soft Cream                            1          1
# Your Skin But Better™ CC+™ Cream with SPF 50+          1          1
# ...                                                  ...        ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...     0          0
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...     1          1
# Daily Deflector™ Waterlight Broad Spectrum SPF ...     0          0
# Self Tan Dry Oil SPF 50                                0          0
# Pro Light Self Tan Bronzing Mist                       0          0
#
#                                                              X          Y
# Name
# Crème de la Mer                                     100.122452 -24.029751
# Facial Treatment Essence                            105.558647 -25.739443
# Protini™ Polypeptide Cream                          107.661148 -23.679094
# The Moisturizing Soft Cream                         100.912407 -25.774166
# Your Skin But Better™ CC+™ Cream with SPF 50+       102.269592 -27.337883
# ...                                                        ...        ...
# Daily Deflector™ Moisturizer Broad Spectrum SPF...  105.120941 -27.022434
# Yoghurt Nourishing Fluid Veil Face Sunscreen Br...  108.706017 -24.069988
# Daily Deflector™ Waterlight Broad Spectrum SPF ...  105.001213 -27.528728
# Self Tan Dry Oil SPF 50                             108.959030 -24.718243
# Pro Light Self Tan Bronzing Mist                    107.996140 -26.808599
#
# [1284 rows x 12 columns]

# %%
CD['Distance'] = 0.0

# %%
myItem2 = CD.loc[[choiceProduct]]

point1 = np.array([myItem2['X'], myItem2['Y']])
point1
# Out:
# array([[105.41346 ],
#        [-30.305857]], dtype=float32)

# %%
# other items

for i in range(len(CD)):
    point2 = np.array([CD['X'][i], CD['Y'][i]])
    CD.Distance[i] = dist(point1, point2)
# Out:
# <ipython-input-31-6f842e3f8e3d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CD.Distance[i] = dist(point1, point2)

# %%
# sorting data in ascending order

CD = CD.sort_values('Distance')
CD.head(6)
# Out:
#                                                         Label           Brand  \
# Name
# Purity Made Simple Cleanser                          Cleanser      PHILOSOPHY
# Clinique Smart Custom-Repair Serum                  Treatment        CLINIQUE
# Perfectionist Pro Rapid Firm + Lift Treatment       Treatment    ESTÉE LAUDER
# Purity Made Simple® Facial Cleansing Gel & Eye ...   Cleanser      PHILOSOPHY
# Clinique Smart Custom-Repair Eye Treatment          Eye cream        CLINIQUE
# Baby Pekee Bar™ + Juju Bar Travel Duo                Cleanser  DRUNK ELEPHANT
#
#                                                     Price  Rank  \
# Name
# Purity Made Simple Cleanser                            24   4.5
# Clinique Smart Custom-Repair Serum                     60   4.0
# Perfectionist Pro Rapid Firm + Lift Treatment          75   5.0
# Purity Made Simple® Facial Cleansing Gel & Eye ...     23   0.0
# Clinique Smart Custom-Repair Eye Treatment             50   3.7
# Baby Pekee Bar™ + Juju Bar Travel Duo                  18   4.5
#
#                                                                                           Ingredients  \
# Name
# Purity Made Simple Cleanser                         Water, Sodium Lauroamphoacetate, Sodium Tridec...
# Clinique Smart Custom-Repair Serum                  Water , Isododecane , Dimethicone , Cyclopenta...
# Perfectionist Pro Rapid Firm + Lift Treatment       Perfectionist Pro Rpd Frm+Lift Trt Division: E...
# Purity Made Simple® Facial Cleansing Gel & Eye ...  Water, Sodium Trideceth Sulfate, Disodium Laur...
# Clinique Smart Custom-Repair Eye Treatment          Water , Isododecane , Dimethicone , Cyclopenta...
# Baby Pekee Bar™ + Juju Bar Travel Duo               -Heilmoor Clay: Tones and detoxifies the skin....
#
#                                                     Combination  Dry  Normal  \
# Name
# Purity Made Simple Cleanser                                   1    1       1
# Clinique Smart Custom-Repair Serum                            1    1       1
# Perfectionist Pro Rapid Firm + Lift Treatment                 1    1       1
# Purity Made Simple® Facial Cleansing Gel & Eye ...            0    0       0
# Clinique Smart Custom-Repair Eye Treatment                    0    0       0
# Baby Pekee Bar™ + Juju Bar Travel Duo                         1    1       1
#
#                                                     Oily  Sensitive  \
# Name
# Purity Made Simple Cleanser                            1          1
# Clinique Smart Custom-Repair Serum                     1          1
# Perfectionist Pro Rapid Firm + Lift Treatment          1          0
# Purity Made Simple® Facial Cleansing Gel & Eye ...     0          0
# Clinique Smart Custom-Repair Eye Treatment             0          0
# Baby Pekee Bar™ + Juju Bar Travel Duo                  1          0
#
#                                                              X          Y  \
# Name
# Purity Made Simple Cleanser                         105.413460 -30.305857
# Clinique Smart Custom-Repair Serum                  105.763672 -30.150152
# Perfectionist Pro Rapid Firm + Lift Treatment       105.096970 -29.975204
# Purity Made Simple® Facial Cleansing Gel & Eye ...  105.954903 -30.292883
# Clinique Smart Custom-Repair Eye Treatment          105.551170 -29.742168
# Baby Pekee Bar™ + Juju Bar Travel Duo               104.983391 -29.850033
#
#                                                     Distance
# Name
# Purity Made Simple Cleanser                         0.000000
# Clinique Smart Custom-Repair Serum                  0.383265
# Perfectionist Pro Rapid Firm + Lift Treatment       0.457708
# Purity Made Simple® Facial Cleansing Gel & Eye ...  0.541598
# Clinique Smart Custom-Repair Eye Treatment          0.580266
# Baby Pekee Bar™ + Juju Bar Travel Duo               0.626686
